# %%
import torch
from torch.autograd import Variable
import numpy as np

# %%
xy = np.loadtxt('data-diabetes.csv', delimiter=',', dtype=np.float32)

x_data = Variable(torch.from_numpy(xy[:,0:-1]))
y_data = Variable(torch.from_numpy(xy[:,[-1]]))

print(x_data.data.shape)
print(y_data.data.shape)
# Out:
# torch.Size([759, 8])
# torch.Size([759, 1])

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.l1 = torch.nn.Linear(8, 32)
        self.l2 = torch.nn.Linear(32, 32)
        self.l3 = torch.nn.Linear(32, 16)
        self.l4 = torch.nn.Linear(16, 16)
        self.l5 = torch.nn.Linear(16, 8)
        self.l6 = torch.nn.Linear(8, 8)
        self.l7 = torch.nn.Linear(8, 4)
        self.l8 = torch.nn.Linear(4, 4)
        self.l9 = torch.nn.Linear(4, 2)
        self.l10 = torch.nn.Linear(2, 1)
        
#         self.activation = torch.nn.Sigmoid()
#         self.activation = torch.nn.ReLu()
        self.activation = torch.nn.Softmax()
        
    def forward(self, x):
        out1 = self.activation(self.l1(x))
        out2 = self.activation(self.l2(out1))
        out3 = self.activation(self.l3(out2))
        out4 = self.activation(self.l4(out3))
        out5 = self.activation(self.l5(out4))
        out6 = self.activation(self.l6(out5))
        out7 = self.activation(self.l7(out6))
        out8 = self.activation(self.l8(out7))
        out9 = self.activation(self.l9(out8))
        y_pred = self.activation(self.l10(out9))
        return y_pred

# %%
model = Model()
criterion = torch.nn.BCELoss(size_average=True)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
for epoch in range(100):
    y_pred = model(x_data)
    
    loss = criterion(y_pred, y_data)
    print(epoch, loss.data[0], y_pred[:5], y_data[:5])
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# 0 9.57436752319336 Variable containing:
#  1
#  1
#  1
#  1
#  1
# [torch.FloatTensor of size 5x1]
#  Variable containing:
#  0
#  1
#  0
#  1
#  0
# [torch.FloatTensor of size 5x1]
#
# 1 9.57436752319336 Variable containing:
#  1
#  1
#  1
#  1
#  1
# [torch.FloatTensor of size 5x1]
#  Variable containing:
#  0
#  1
#  0
#  1
#  0
# [torch.FloatTensor of size 5x1]
#
# 2 9.57436752319336 Variable containing:
#  1
#  1
#  1
#  1
#  1
# [torch.FloatTensor of size 5x1]
#  Variable containing:
#  0
#  1
#  0
#  1
#  0
# [torch.FloatTensor of size 5x1]
#
# 3 9.57436752319336 Variable containing:
#  1
#  1
#  1
#  1
#  1
# [torch.FloatTensor of size 5x1]
#  Variable containing:
#  0
#  1
#  0
#  1
#  0
# [torch.FloatTensor of size 5x1]
#
# 4 9.57436752319336 Variable containing:
#  1
#  1
#  1
#  1
#  1
# [torch.FloatTensor of size 5x1]
#  Variable containing:
#  0
#  1
#  0
#  1
#  0
# [torch.FloatTensor of size 5x1]
#
# 5 9.57436752319336 Variable containing:
#  1
#  1
#  1
#  1
#  1
# ...
